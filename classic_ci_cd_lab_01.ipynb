# %%
# !pip install scikit-learn pandas numpy joblib fastapi uvicorn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
import joblib
import os

if not os.path.exists("data.csv"):
    df = pd.DataFrame({
        "text": [
            "This product is amazing and useful",
            "The service is extremely bad",
            "The experience is somewhat good",
            "Highly recommend using it",
            "I will not buy again"
        ],
        "label": ["positive", "negative", "neutral", "positive", "negative"]
    })
    df.to_csv("data.csv", index=False)
else:
    df = pd.read_csv("data.csv")

X_train, X_test, y_train, y_test = train_test_split(
    df["text"], df["label"], test_size=0.2, random_state=42
)

print("data.csv loaded successfully, train/test split completed.")
# Out:
# data.csv loaded successfully, train/test split completed.

# %%
model = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', LogisticRegression())
])
model.fit(X_train, y_train)
joblib.dump(model, "model.pkl")
# Out:
# ['model.pkl']

# %%
# pseudo code to push model to GitHub
# automated pipeline will replace this step

# %%
from fastapi import FastAPI
import joblib

app = FastAPI()
model = joblib.load("model.pkl")

@app.post("/predict")
def predict(text: str):
    return {"prediction": model.predict([text])[0]}
